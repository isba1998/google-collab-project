# %% [markdown]
# <a href="https://colab.research.google.com/github/isba1998/google-collab-project/blob/main/DNA_Sequence_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Counting DNA Nucleotides
#
# This project uses Python to count DNA Nucleotide of given sequesnce.

# %%
dna_seq=("...")
print(dna_seq.count("A"))
print(dna_seq.count("C"))
print(dna_seq.count("G"))
print(dna_seq.count("T"))
# Out:
# 233
# 241
# 243
# 236

# %% [markdown]
# # Transcribing DNA into RNA
#
# Transcribed RNA string of t

# %%
dna_seq="..."
print(dna_seq.replace("T","U"))
# Out:
# ...

# %% [markdown]
# # Complementing a Strand of DNA

# %%
dna_seq="AAAACCCGGT"
print(reverse_complement(dna_seq))
# Out:
# ACCGGGTTTT

# %% [markdown]
# # Computing GC Content
